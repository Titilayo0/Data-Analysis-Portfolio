# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("pizza_sales.csv")
df.columns
# Out:
# Index(['pizza_id', 'order_id', 'pizza_name_id', 'quantity', 'order_date',
#        'order_time', 'unit_price', 'total_price', 'pizza_size',
#        'pizza_category', 'pizza_ingredients', 'pizza_name'],
#       dtype='object')

# %%
df.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0       1.0       1.0     hawaiian_m       1.0   1/1/2015   11:38:36
# 1       2.0       2.0  classic_dlx_m       1.0   1/1/2015   11:57:40
# 2       3.0       2.0  five_cheese_l       1.0   1/1/2015   11:57:40
# 3       4.0       2.0    ital_supr_l       1.0   1/1/2015   11:57:40
# 4       5.0       2.0     mexicana_m       1.0   1/1/2015   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# ...

# %%
df.isnull().sum()
# Out:
# pizza_id             0
# order_id             0
# pizza_name_id        0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
df['pizza_ingredients'].count()
# Out:
# 48620

# %%
unique_ingredient = df['pizza_ingredients'].nunique()
unique_ingredient
# Out:
# 32

# %%
#df['pizza_ingredients'].unique()

# %%
df[df['pizza_ingredients'] == 'Sliced Ham, Pineapple, Mozzarella Cheese'].count()
# Out:
# pizza_id             2370
# order_id             2370
# pizza_name_id        2370
# quantity             2370
# order_date           2370
# order_time           2370
# unit_price           2370
# total_price          2370
# pizza_size           2370
# pizza_category       2370
# pizza_ingredients    2370
# pizza_name           2370
# dtype: int64

# %%
df['pizza_category'].nunique()
# Out:
# 4

# %%
df['pizza_category'].unique()
# Out:
# array(['Classic', 'Veggie', 'Supreme', 'Chicken'], dtype=object)

# %%
df['pizza_size'].nunique()
# Out:
# 5

# %%
df[df['pizza_name'] =='The Mediterranean Pizza'].count()
# Out:
# pizza_id             923
# order_id             923
# pizza_name_id        923
# quantity             923
# order_date           923
# order_time           923
# unit_price           923
# total_price          923
# pizza_size           923
# pizza_category       923
# pizza_ingredients    923
# pizza_name           923
# dtype: int64

# %%
#sum of all total_price values
total_sales = df['total_price'].sum()
total_sales
# Out:
# 817860.05

# %%
#average value of the total_price
average_total_sales = df['total_price'].mean()
avg_total_sales = float(round(average_total_sales, 2))
avg_total_sales
# Out:
# 16.82

# %%
# the average value of the unit_price
average_unit_price = df['unit_price'].mean()
avg_unit_price = float(round(average_unit_price,2))
avg_unit_price
# Out:
# 16.49

# %%
#highest and lowest values of the unit_price
max_unit_price = df['unit_price'].max()
max_unit_price
# Out:
# 35.95

# %%
min_unit_price = df['unit_price'].min()
min_unit_price
# Out:
# 9.75

# %%
#sum of all quantity
total_quantity_sold = df['quantity'].sum()
total_quantity_sold
# Out:
# 49574.0

# %%
#profit margin percentage, calculated as (total_price - cost) / total_price * 100
# Your cost calculation here -there was no cost_per_unit in this case
cost_per_unit = df['profit_margin'] = ((df['total_price'] 
                                        - (df['quantity'] * cost_per_unit)) 
                                       / df['total_price']) * 100

# %%
#total revenue, calculated as total_price - cost
# Your cost calculation here
cost_per_unit =df['total_revenue'] = df['total_price'] 
- (df['quantity'] * cost_per_unit)
# Out:
# 0       -13.25
# 1       -16.00
# 2       -18.50
# 3       -20.75
# 4       -16.00
#          ...
# 48615   -16.75
# 48616   -17.95
# 48617   -12.00
# 48618   -20.25
# 48619   -12.75
# Length: 48620, dtype: float64

# %%
#df[df['quantity']>1].count()

# %%
sns.set_theme()

# %%
sns.relplot(data = df,
            x = 'total_price', y ='unit_price', col = 'pizza_size', 
            hue = 'pizza_name', style= 'pizza_name', size = 'quantity')  #hue- colour option

# %%
sns.set_theme() 
#sns.set_style('whitegrid')
sns.set_style('dark')

# %%
sns.relplot(data = df, x= 'pizza_category', y = 'pizza_size',
            col= 'quantity',
           hue = 'quantity', style= 'quantity', size = 'pizza_category')
