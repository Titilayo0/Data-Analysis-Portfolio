# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Content.csv")
df.head()
# Out:
#    Unnamed: 0                            Content ID Content Type  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f        photo
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6        photo
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180        video
#
#          Category
# 0        Studying
# 1  healthy eating
# 2  healthy eating
# 3      technology
# 4            food

# %%
reactions = pd.read_csv("Reactions.csv")
reactions.head()
# Out:
#    Unnamed: 0                            Content ID Reaction Type  \
# 0           1  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1           2  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2           3  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3           4  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4           5  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
#
#            Datetime Content Type  Category Sentiment  Score
# 0  07/11/2020 09:43        photo  Studying  negative      0
# 1  17/06/2021 12:22        photo  Studying  negative     10
# 2  18/04/2021 05:13        photo  Studying  negative     15
# 3  06/01/2021 19:13        photo  Studying  negative      0
# 4  23/08/2020 12:25        photo  Studying  positive     30

# %%
#df.head()
#df.columns
df.rename(columns= {"Unnamed":"no"}, inplace = True)
#df.columns
#df.isnull().sum()
#df = pd.read_csv("C:/Users/User/desktop/Content.csv")
if 'Unnamed: 0' in df.columns:
    df.drop('Unnamed: 0', axis=1, inplace=True)
try:
    df = df.drop(columns=['User ID','URL'])
except KeyError as e:
    print(f"KeyError: {e}")
    
df.head()
# Out:
# KeyError: "['User ID', 'URL'] not found in axis"
#                              Content ID Content Type        Category
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo        Studying
# 1  9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo  healthy eating
# 2  230c4e4d-70c3-461d-b42c-ec09396efb3f        photo  healthy eating
# 3  356fff80-da4d-4785-9f43-bc1261031dc6        photo      technology
# 4  01ab84dd-6364-4236-abbb-3f237db77180        video            food

# %%
df.head()
# Out:
#                              Content ID Content Type        Category
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo        Studying
# 1  9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo  healthy eating
# 2  230c4e4d-70c3-461d-b42c-ec09396efb3f        photo  healthy eating
# 3  356fff80-da4d-4785-9f43-bc1261031dc6        photo      technology
# 4  01ab84dd-6364-4236-abbb-3f237db77180        video            food

# %%
df.drop(['User ID'], axis=1, inplace=True, errors = "ignore")
df.head()
# Out:
#                              Content ID Content Type        Category
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2        photo        Studying
# 1  9f737e0a-3cdd-4d29-9d24-753f4e3be810        photo  healthy eating
# 2  230c4e4d-70c3-461d-b42c-ec09396efb3f        photo  healthy eating
# 3  356fff80-da4d-4785-9f43-bc1261031dc6        photo      technology
# 4  01ab84dd-6364-4236-abbb-3f237db77180        video            food

# %%
reactions = pd.read_csv("ReactionTypes.csv")
reactions.head()
# Out:
#    Unnamed: 0 Reaction Type Sentiment  Score
# 0           0         heart  positive     60
# 1           1          want  positive     70
# 2           2       disgust  negative      0
# 3           3          hate  negative      5
# 4           4    interested  positive     30

# %%
df1 = pd.read_csv("Reactions.csv")
df1.head()
# Out:
#    Unnamed: 0                            Content ID Reaction Type  \
# 0           1  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1           2  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2           3  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3           4  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4           5  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
#
#            Datetime Content Type  Category Sentiment  Score
# 0  07/11/2020 09:43        photo  Studying  negative      0
# 1  17/06/2021 12:22        photo  Studying  negative     10
# 2  18/04/2021 05:13        photo  Studying  negative     15
# 3  06/01/2021 19:13        photo  Studying  negative      0
# 4  23/08/2020 12:25        photo  Studying  positive     30

# %%
#df.head()
#df.columns
#df1.rename(columns= {"Unnamed":"no"}, inplace = True)
#df1.columns
#df.isnull().sum()
df1 = pd.read_csv("Reactions.csv")
if 'Unnamed: 0' in df1.columns:
    df1.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df1.head()
# Out:
#                              Content ID Reaction Type          Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  07/11/2020 09:43
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  17/06/2021 12:22
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared  18/04/2021 05:13
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  06/01/2021 19:13
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested  23/08/2020 12:25
#
#   Content Type  Category Sentiment  Score
# 0        photo  Studying  negative      0
# 1        photo  Studying  negative     10
# 2        photo  Studying  negative     15
# 3        photo  Studying  negative      0
# 4        photo  Studying  positive     30

# %%
df1.drop(['User ID'], axis=1, inplace=True, errors = "ignore")
df1.head()
# Out:
#                              Content ID Reaction Type          Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  07/11/2020 09:43
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  17/06/2021 12:22
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared  18/04/2021 05:13
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  06/01/2021 19:13
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested  23/08/2020 12:25
#
#   Content Type  Category Sentiment  Score
# 0        photo  Studying  negative      0
# 1        photo  Studying  negative     10
# 2        photo  Studying  negative     15
# 3        photo  Studying  negative      0
# 4        photo  Studying  positive     30

# %%
df1.isnull().sum()
# Out:
# Content ID       0
# Reaction Type    0
# Datetime         0
# Content Type     0
# Category         0
# Sentiment        0
# Score            0
# dtype: int64

# %%
df1.rename(columns= {"Type":"Reaction Type"}, inplace = True)

# %%
df1.head()
# Out:
#                              Content ID Reaction Type          Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  07/11/2020 09:43
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  17/06/2021 12:22
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared  18/04/2021 05:13
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  06/01/2021 19:13
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested  23/08/2020 12:25
#
#   Content Type  Category Sentiment  Score
# 0        photo  Studying  negative      0
# 1        photo  Studying  negative     10
# 2        photo  Studying  negative     15
# 3        photo  Studying  negative      0
# 4        photo  Studying  positive     30

# %%
df1.dropna(subset=['Reaction Type'], inplace=True)

# %%
df1.head()
# Out:
#                              Content ID Reaction Type          Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  07/11/2020 09:43
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  17/06/2021 12:22
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared  18/04/2021 05:13
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  06/01/2021 19:13
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested  23/08/2020 12:25
#
#   Content Type  Category Sentiment  Score
# 0        photo  Studying  negative      0
# 1        photo  Studying  negative     10
# 2        photo  Studying  negative     15
# 3        photo  Studying  negative      0
# 4        photo  Studying  positive     30

# %%
merged_df = pd.merge(df1, df, on='Content ID', how='inner')

# %%
merged_df.head()
# Out:
#                              Content ID Reaction Type          Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  07/11/2020 09:43
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  17/06/2021 12:22
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared  18/04/2021 05:13
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  06/01/2021 19:13
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested  23/08/2020 12:25
#
#   Content Type_x Category_x Sentiment  Score Content Type_y Category_y
# 0          photo   Studying  negative      0          photo   Studying
# 1          photo   Studying  negative     10          photo   Studying
# 2          photo   Studying  negative     15          photo   Studying
# 3          photo   Studying  negative      0          photo   Studying
# 4          photo   Studying  positive     30          photo   Studying

# %%
merged_df.rename(columns= {"Type":"Content Type"}, inplace = True)

# %%
merged_df.head()
# Out:
#                              Content ID Reaction Type          Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  07/11/2020 09:43
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike  17/06/2021 12:22
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2        scared  18/04/2021 05:13
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  06/01/2021 19:13
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2    interested  23/08/2020 12:25
#
#   Content Type_x Category_x Sentiment  Score Content Type_y Category_y
# 0          photo   Studying  negative      0          photo   Studying
# 1          photo   Studying  negative     10          photo   Studying
# 2          photo   Studying  negative     15          photo   Studying
# 3          photo   Studying  negative      0          photo   Studying
# 4          photo   Studying  positive     30          photo   Studying

# %%
df3 = pd.read_csv("ReactionTypes.csv")
df3.rename(columns= {"Type":"Content Type"}, inplace = True)
df3 = pd.read_csv("ReactionTypes.csv")
if 'Unnamed: 0' in df3.columns:
    df3.drop('Unnamed: 0', axis=1, inplace=True)
df3.head()
# Out:
#   Reaction Type Sentiment  Score
# 0         heart  positive     60
# 1          want  positive     70
# 2       disgust  negative      0
# 3          hate  negative      5
# 4    interested  positive     30

# %%
df3.rename(columns= {"Type":"Reaction Type"}, inplace = True)
df3.head()
# Out:
#   Reaction Type Sentiment  Score
# 0         heart  positive     60
# 1          want  positive     70
# 2       disgust  negative      0
# 3          hate  negative      5
# 4    interested  positive     30

# %%
merged_data_df = pd.merge(merged_df, df3, on='Reaction Type', how='inner')

# %%
merged_data_df.head()
# Out:
#                              Content ID Reaction Type          Datetime  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  07/11/2020 09:43
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  06/01/2021 19:13
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust  09/04/2021 02:46
# 3  9f737e0a-3cdd-4d29-9d24-753f4e3be810       disgust  28/03/2021 21:15
# 4  230c4e4d-70c3-461d-b42c-ec09396efb3f       disgust  04/08/2020 05:40
#
#   Content Type_x      Category_x Sentiment_x  Score_x Content Type_y  \
# 0          photo        Studying    negative        0          photo
# 1          photo        Studying    negative        0          photo
# 2          photo        Studying    negative        0          photo
# 3          photo  healthy eating    negative        0          photo
# 4          photo  healthy eating    negative        0          photo
#
#        Category_y Sentiment_y  Score_y
# 0        Studying    negative        0
# 1        Studying    negative        0
# 2        Studying    negative        0
# 3  healthy eating    negative        0
# 4  healthy eating    negative        0

# %%
merged_data_df.columns
# Out:
# Index(['Content ID', 'Reaction Type', 'Datetime', 'Content Type_x',
#        'Category_x', 'Sentiment_x', 'Score_x', 'Content Type_y', 'Category_y',
#        'Sentiment_y', 'Score_y'],
#       dtype='object')

# %%
#merged_data_df.drop(columns = ['Category_x'], inplace=True)
#merged_data_df.head()

# %%
# Group by 'Category' and calculate the sum of 'Score'
category_scores = merged_data_df.groupby('Category')['Score'].sum()
#popular_categories =merged_data_df['Category'].value_counts()
#popular_categories
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 2
#       1 # Group by 'Category' and calculate the sum of 'Score'
# ----> 2 category_scores = merged_data_df.groupby('Category')['Score'].sum()
#       3 #popular_categories =merged_data_df['Category'].value_counts()
#       4 #popular_categories
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:8869, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8866 if level is None and by is None:
#    8867     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8869 return DataFrameGroupBy(
#    8870     obj=self,
#    8871     keys=by,
#    8872     axis=axis,
#    8873     level=level,
#    8874     as_index=as_index,
#    8875     sort=sort,
#    8876     group_keys=group_keys,
#    8877     observed=observed,
#    8878     dropna=dropna,
#    8879 )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1278, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1275 self.dropna = dropna
#    1277 if grouper is None:
# -> 1278     grouper, exclusions, obj = get_grouper(
#    1279         obj,
#    1280         keys,
#    1281         axis=axis,
#    1282         level=level,
#    1283         sort=sort,
#    1284         observed=False if observed is lib.no_default else observed,
#    1285         dropna=self.dropna,
#    1286     )
#    1288 if observed is lib.no_default:
#    1289     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\grouper.py:1009, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1007         in_axis, level, gpr = False, gpr, None
#    1008     else:
# -> 1009         raise KeyError(gpr)
#    1010 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1011     # Add key to exclusions
#    1012     exclusions.add(gpr.key)
#
# KeyError: 'Category'

# %%
category_counts = merged_data_df['Category'].value_counts()
#category_counts

# %%
merged_data_df.isnull().sum()
# Out:
# Content ID       0
# Reaction Type    0
# Datetime         0
# Content Type     0
# Category         0
# Sentiment        0
# Score            0
# dtype: int64

# %%
merged_data_df['Category'] = merged_data_df['Category'].str.replace('"', '')

# %%
merged_data_df
# Out:
#                                  Content ID Reaction Type  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 3      9f737e0a-3cdd-4d29-9d24-753f4e3be810       disgust
# 4      230c4e4d-70c3-461d-b42c-ec09396efb3f       disgust
# ...                                     ...           ...
# 24568  435007a5-6261-4d8b-b0a4-55fdc189754b         adore
# 24569  435007a5-6261-4d8b-b0a4-55fdc189754b         adore
# 24570  4e4c9690-c013-4ee7-9e66-943d8cbd27b7         adore
# 24571  4e4c9690-c013-4ee7-9e66-943d8cbd27b7         adore
# 24572  4e4c9690-c013-4ee7-9e66-943d8cbd27b7         adore
#
#                   Datetime Content Type        Category Sentiment  Score
# 0      2020-11-07 09:43:50        photo        Studying  negative      0
# 1      2021-01-06 19:13:01        photo        Studying  negative      0
# 2      2021-04-09 02:46:20        photo        Studying  negative      0
# 3      2021-03-28 21:15:26        photo  healthy eating  negative      0
# 4      2020-08-04 05:40:33        photo  healthy eating  negative      0
# ...                    ...          ...             ...       ...    ...
# 24568  2020-10-04 22:26:33        audio        veganism  positive     72
# 24569  2020-09-18 10:50:50        audio        veganism  positive     72
# 24570  2020-10-31 03:58:44          GIF         culture  positive     72
# 24571  2020-06-25 15:12:29          GIF         culture  positive     72
# 24572  2020-12-17 16:32:57          GIF         culture  positive     72
#
# [24573 rows x 7 columns]

# %%
merged_data_df['Category'] = merged_data_df['Category'].str.capitalize()

# %%
unique_categories_count = merged_data_df['Category'].nunique()

# %%
unique_categories_count
# Out:
# 16

# %%
# Group by 'Category' and calculate the sum of 'Score'
category_scores = merged_data_df.groupby('Category')['Score'].sum()

# %%
category_scores
# Out:
# Category
# Animals            74965
# Cooking            64756
# Culture            66579
# Dogs               52511
# Education          57436
# Fitness            55323
# Food               66676
# Healthy eating     69339
# Public speaking    49264
# Science            71168
# Soccer             57783
# Studying           54269
# Technology         68738
# Tennis             50339
# Travel             64880
# Veganism           49619
# Name: Score, dtype: int64

# %%
top_categories = category_scores.nlargest(5)

# %%
top_categories
# Out:
# Category
# Animals           74965
# Science           71168
# Healthy eating    69339
# Technology        68738
# Food              66676
# Name: Score, dtype: int64

# %%
bottom_categories = category_scores.nsmallest(5)

# %%
bottom_categories
# Out:
# Category
# Public speaking    49264
# Veganism           49619
# Tennis             50339
# Dogs               52511
# Studying           54269
# Name: Score, dtype: int64

# %%
category_scores = pd.Series({'Animals': 74965, 'Science': 71168, 'Healthy eating': 69339, 'Technology': 68738, 'Food': 66676})

# Convert the Series to a DataFrame
popular_categories = pd.DataFrame({'Category': category_scores.index, 'Aggregate Score': category_scores.values})

popular_categories['Aggregate Score'] =popular_categories['Aggregate Score']
# Out:
#          Category  Aggregate Score
# 0         Animals            74965
# 1         Science            71168
# 2  Healthy eating            69339
# 3      Technology            68738
# 4            Food            66676

# %%
popular_categories
# Out:
#          Category  Aggregate Score
# 0         Animals            74965
# 1         Science            71168
# 2  Healthy eating            69339
# 3      Technology            68738
# 4            Food            66676

# %%
popular_categories.plot(kind="bar")
plt.xlabel("Category")
plt.ylabel("Aggregate Score")
plt.title("5 popular Categories")
plt.show()
